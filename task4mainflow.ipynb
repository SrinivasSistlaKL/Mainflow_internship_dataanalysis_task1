# %% [markdown]
# <a href="https://colab.research.google.com/github/SrinivasSistlaKL/Mainflow_internship_dataanalysis_task1/blob/main/task4mainflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('synthetic_dataset.csv')

# %%
# Display the first few rows
print(data.head())

# Get the data types and non-null counts
print(data.info())
# Out:
#    age  income  credit_score  purchase_amount  gender    city
# 0   56   81228           715      2198.102327    Male  City_A
# 1   69   68984           546      4836.608613  Female  City_A
# 2   46   60774           738      4821.737888  Female  City_C
# 3   32   22568           502      4279.746332  Female  City_A
# 4   60   82592           483      1542.799571    Male  City_C
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              100 non-null    int64
#  1   income           100 non-null    int64
#  2   credit_score     100 non-null    int64
#  3   purchase_amount  100 non-null    float64
#  4   gender           100 non-null    object
#  5   city             100 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 4.8+ KB
# None

# %%
# Summary statistics
print(data.describe())

# Check for missing values
print(data.isnull().sum())
# Out:
#               age        income  credit_score  purchase_amount
# count  100.000000    100.000000    100.000000       100.000000
# mean    43.350000  60459.590000    568.450000      2566.779762
# std     14.904663  23134.012968    154.009797      1391.525311
# min     19.000000  20206.000000    301.000000       170.528094
# 25%     31.750000  42218.250000    446.750000      1495.958125
# 50%     42.000000  63263.000000    557.500000      2649.403635
# 75%     57.000000  81264.250000    702.250000      3672.309374
# max     69.000000  99575.000000    846.000000      4951.263866
# age                0
# income             0
# credit_score       0
# purchase_amount    0
# gender             0
# city               0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for each numerical variable
data.hist(figsize=(10, 8), bins=20)
plt.show()

# %%
# Boxplot for each numerical variable
plt.figure(figsize=(10, 8))
sns.boxplot(data=data)
plt.xticks(rotation=90)
plt.show()

# %%
# Select only numeric columns
import numpy as np

numeric_data = data.select_dtypes(include=[np.number])

# Correlation matrix
corr_matrix = numeric_data.corr()

# Heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
